# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB

# %%
#loading the data and splitting into train and test sets
data = pd.read_csv("text1.csv")
data.head(10)
X = data[["No_of_Followers","No_Following","WtAvg"]]
Y = data[["Spam"]]
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
#scatter matrix
scatter_matrix(data)
plt.show()

# %%
# histograms
data.hist()
plt.show()

# %%
#SVM
clf = SVC(kernel='linear') 
clf.fit(x_train, y_train)
n = accuracy_score(y_test, clf.predict(x_test))
print(n)
# Out:
# C:\Users\aritr\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5

# %%
#Naive Bayes

clf = GaussianNB() 
clf.fit(x_train, y_train) 
p = accuracy_score(y_test, clf.predict(x_test))
print(p)
# Out:
# 0.4
# C:\Users\aritr\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#MLP

clf = MLPClassifier(hidden_layer_sizes=(13,13,13),max_iter=500)
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)
# Out:
# C:\Users\aritr\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:916: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(accuracy_score(y_test, predictions))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# 0.8
# [[6 1]
#  [1 2]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86         7
#            1       0.67      0.67      0.67         3
#
#    micro avg       0.80      0.80      0.80        10
#    macro avg       0.76      0.76      0.76        10
# weighted avg       0.80      0.80      0.80        10
